# %% [markdown]
# # On commence le projet par l'importation des librairies nécessaires au bon fonctionnement de ce dernier.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importation du csv utilisé par nos diagrammes.

# %%
df = pd.read_csv('anime_cleaned.csv')
df
# Out:
#       anime_id                                              title  \
# 0        11013                                      Inu x Boku SS
# 1         2104                                   Seto no Hanayome
# 2         5262                                 Shugo Chara!! Doki
# 3          721                                      Princess Tutu
# 4        12365                                Bakuman. 3rd Season
# ...        ...                                                ...
# 6663     37405                            Dokidoki Little Ooyasan
# 6664     37886                        Wo Shi Jiang Xiaobai (2018)
# 6665     37255              Genki Genki Non-tan: Obake Mura Meiro
# 6666     35229                                Mr. Men Little Miss
# 6667     36315  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...
#
#                   title_english                      title_japanese  \
# 0     Inu X Boku Secret Service                              妖狐×僕SS
# ...

# %% [markdown]
# ## Suppression des colonnes inutiles pour le dérouler du projet, et triage par Rank.

# %%
pd.set_option('display.max_columns', None)
df0 = df.drop(['title_english', 'title_japanese', 'title_synonyms', 'image_url', 'airing', 'aired_string', 'aired', 'duration', 'rating','background', 'broadcast', 'related', 'opening_theme', 'ending_theme'], axis = 1)
df0['aired_from_year'] = df0['aired_from_year'].astype(int)
df0 = df0.dropna(subset = ['rank'])
df0 = df0.set_index("rank")
df0
# Out:
#          anime_id                                              title type  \
# rank
# 1274.0      11013                                      Inu x Boku SS   TV
# 727.0        2104                                   Seto no Hanayome   TV
# 1508.0       5262                                 Shugo Chara!! Doki   TV
# 307.0         721                                      Princess Tutu   TV
# 50.0        12365                                Bakuman. 3rd Season   TV
# ...           ...                                                ...  ...
# 11126.0     37894                                 Ling Yu 4th Season  ONA
# 12719.0     37886                        Wo Shi Jiang Xiaobai (2018)  ONA
# 10253.0     37255              Genki Genki Non-tan: Obake Mura Meiro  OVA
# 11396.0     35229                                Mr. Men Little Miss  ONA
# 11396.0     36315  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...  OVA
#
#                source  episodes            status  score  scored_by  \
# ...

# %% [markdown]
# # Création d'un premier diagrame, une boîte à moustache, afin d'afficher les statistiques des scores des animes.

# %% [markdown]
# ## On commence par filtrer nos animes en question.

# %%
df1 = df0.drop(['type', 'source', 'episodes', 'status', 'popularity', 'members','favorites', 'premiered', 'producer', 'licensor', 'studio', 'genre', 'duration_min', 'aired_from_year'], axis = 1)
df1.sort_values('score', ascending=False)
# Out:
#          anime_id                                              title  score  \
# rank
# 1.0          5114                   Fullmetal Alchemist: Brotherhood   9.25
# 2.0         32281                                     Kimi no Na wa.   9.19
# 3.0         28977                                           Gintama°   9.15
# 4.0         30484                                      Steins;Gate 0   9.15
# 5.0          9253                                        Steins;Gate   9.14
# ...           ...                                                ...    ...
# 10119.0     37859  Free! Movie 2: Timeless Medley - Yakusoku: Cha...   0.00
# 10120.0     37860    Free!: Take Your Marks: Character Butai Aisatsu   0.00
# 10587.0     37814     Inazuma Eleven Reloaded: Reformation of Soccer   0.00
# 9913.0      37494                             Chikyuu to no Yakusoku   0.00
# 12719.0     37886                        Wo Shi Jiang Xiaobai (2018)   0.00
#
#          scored_by
# rank
# 1.0         733592
# ...

# %% [markdown]
# ## Puis création du diagramme.

# %%
plt.figure(figsize = (12,5))
plt.boxplot(df1.score)
plt.title("Boxplot des Scores")
plt.ylim(0,10)
plt.show()

# %% [markdown]
# ## Des valeurs abérentes sont visibles facilement à cause de certaines notations qui n'ont pas assez d'échantillon de personnes.
# ## Il ne manque plus qu'a les enlever et mettre la boîte à moustaches à l'horizontale.

# %%
plt.figure(figsize = (12,5))
plt.boxplot(df1.score, showfliers=False, vert=False)
plt.title("Boxplot des Scores")
plt.xlim(0,10)
plt.show()

# %% [markdown]
# ### On remarque très facilement que les notes osillent entre 4.6 et 9.1 avec une moyenne de 6.9.

# %%
plt.figure(figsize = (12,5))
sns.scatterplot(data = df0, x = df0["aired_from_year"], y = df0["score"])
# Out:
# <AxesSubplot:xlabel='aired_from_year', ylabel='score'>

# %%
plt.figure(figsize = (12,5))
sns.scatterplot(data = df0[(df0["aired_from_year"] >= 2000)], x = "aired_from_year", y = "score")
# Out:
# <AxesSubplot:xlabel='aired_from_year', ylabel='score'>

# %%
df2 = df0.groupby(["aired_from_year"]).mean()
df2
# Out:
#                      anime_id   episodes     score     scored_by  \
# aired_from_year
# 1942             23969.000000   1.000000  6.890000      9.000000
# 1943             13980.500000   1.000000  6.515000    345.000000
# 1944              7523.000000   1.000000  5.260000     95.000000
# 1945              2765.000000   1.000000  5.330000    466.000000
# 1957              6993.000000   1.000000  5.880000    471.000000
# ...                       ...        ...       ...           ...
# 2014             23720.808933  12.076923  6.917742  39091.238213
# 2015             29439.511879  10.276458  6.755140  31368.060475
# 2016             32686.518315   9.948718  6.687729  22105.481685
# 2017             34833.776210   8.401210  6.631109  15980.449597
# 2018             35310.963351   8.036649  6.599110   8491.486911
#
#                    popularity       members   favorites  duration_min
# aired_from_year
# 1942             12255.000000    134.000000    0.000000     11.000000
# ...

# %%
plt.figure(figsize=(12,4))
plt.plot(df2.index, df2.score)
plt.xlabel('axe des x')
plt.ylabel('axe des y')
plt.title('Un graphique avec plusieurs courbes');

# %%
plt.figure(figsize=(12,4))
sns.distplot(df0.score, bins=100)
# Out:
# c:\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='score', ylabel='Density'>

# %%
sns.relplot(x="rank", y="popularity", data = df0, height=8);

# %%
df4 = df0
df4 = df4.groupby(["premiered"]).mean()
df4
# Out:
#                anime_id   episodes     score     scored_by   popularity  \
# premiered
# Fall       12668.119910  31.134615  7.079118  42991.432127  3529.858597
# Spring     12954.047904  31.061876  7.018044  37633.957086  3715.270459
# Summer     15602.992063  19.543651  6.971210  47790.382937  2773.682540
# Winter     14882.184028  26.925347  6.997240  37442.546875  3375.699653
#
#                 members    favorites  duration_min  aired_from_year
# premiered
# Fall       84945.032805  1645.820136     21.143382      2005.218326
# Spring     75917.081836  1439.142715     21.047971      2006.294411
# Summer     94191.428571  1152.539683     20.465278      2009.436508
# Winter     75934.222222   913.758681     20.845747      2007.531250

# %%
plt.figure(figsize=(8,4))
ax = sns.barplot(x = df4.index, y = df4.score, data=random_df, color='red')
ax.set(xlabel='Saisons', ylabel='Score')
plt.show()

# %%
df5 = df0
df5 = df5.groupby(["source"]).mean()
df5
# Out:
#                    anime_id   episodes     score     scored_by    popularity  \
# source
# 4-koma manga   19603.778351  12.252577  6.884381  22691.175258   4070.520619
# Book            9733.068182  23.295455  6.838864   3771.909091   6539.704545
# Card game      23204.630435  20.804348  6.721087   6211.304348   5214.326087
# Digital manga  33064.000000  10.428571  5.610000   9412.000000   3571.285714
# Game           17118.285377  14.202830  6.619717  10780.577830   4671.688679
# Light novel    15995.090730   9.173570  7.250651  62055.238659   1938.065089
# Manga          12753.750000  17.641250  7.142996  29603.406667   3722.307083
# Music          25322.381818   3.363636  6.069636   7412.200000   7964.927273
# Novel          14775.971631  13.929078  6.994504  22058.865248   5218.698582
# Original       15852.740888  14.493736  6.551293  15579.756264   5690.788155
# Other          18566.279762  13.214286  6.181310   7673.779762   6463.904762
# ...

# %%
plt.figure(figsize=(18,4))
ax = sns.barplot(x = df5.index, y = df5.score, data=random_df, color='red')
ax.set(xlabel='Sources', ylabel='Score')
plt.show()

# %%
df6 = df0
df6 = df6.groupby(["type"]).mean()
df6
# Out:
#              anime_id   episodes     score     scored_by   popularity  \
# type
# Movie    14257.873208   1.076075  7.100728  20290.169791  4607.728776
# Music    24459.755102   1.295918  5.965510   2894.683673  8584.918367
# ONA      28832.899015   8.940887  6.064877   4468.115764  7651.990148
# OVA      10291.462926   2.814629  6.731904   9920.268537  4782.925852
# Special  18831.478873   2.773564  6.717356   7963.093174  5203.075840
# TV       13705.891946  28.307383  7.020124  40728.846980  3462.244295
#
#               members    favorites  duration_min  aired_from_year
# type
# Movie    36960.320838   312.562293     71.901488      2004.542448
# Music     4979.316327    28.500000      5.340986      2009.612245
# ONA      10043.847291    60.753695      8.465271      2014.275862
# OVA      19534.053106   108.602204     30.627255      2003.107214
# Special  15422.078007    30.307692     19.470603      2009.442037
# TV       81336.742617  1343.685235     20.875179      2006.765772

# %%
plt.figure(figsize=(10,4))
ax = sns.barplot(x = df6.index, y = df6.score, data=random_df, color='red')
ax.set(xlabel='Types', ylabel='Score')
plt.show()

# %%
df7 = df0
df7 = df7.groupby(["status"]).mean()
df7
# Out:
#                       anime_id   episodes     score    scored_by   popularity  \
# status
# Currently Airing  32264.926380   5.834356  6.407607   7899.08589  6059.030675
# Finished Airing   14680.730851  15.206863  6.876144  25668.51423  4396.309156
#
#                        members   favorites  duration_min  aired_from_year
# status
# Currently Airing  31402.294479  630.343558     14.725153      2015.582822
# Finished Airing   50265.615222  707.228492     28.869762      2006.553261

# %%
plt.figure(figsize=(8,4))
ax = sns.barplot(x = df7.index, y = df7.score, data=random_df, color='red')
ax.set(xlabel='Status', ylabel='Score')
plt.show()

# %%
df2 = df0.groupby(['studio']).mean()
df2 = df2.sort_values('score', ascending=False).head(10)
df2
# Out:
#                                  anime_id  episodes  score  scored_by  \
# studio
# Artland, Magic Bus                  820.0     110.0  9.110    29036.0
# Studio Chizu                      20580.0       1.0  8.635   147708.5
# J.C.Staff, Egg Firm               33933.5      72.0  8.615    36726.0
# Madhouse, Satelight, Graphinica     777.0      10.0  8.530   221939.0
# Xebec, AIC                        12029.0      26.0  8.460    21150.0
# Tezuka Productions, MAPPA         12531.0      12.0  8.440    93986.0
# Studio Ghibli, Studio Hibari        542.0       1.0  8.380   129474.5
# Imagin                             2966.0      13.0  8.340   226529.0
# Gainax, Tatsunoko Production         30.0      26.0  8.320   364012.0
# Studio Gallop, Studio Comet         185.0      26.0  8.280    60560.0
#
#                                  popularity   members  favorites  \
# studio
# Artland, Magic Bus                    671.0  124993.0     8567.0
# ...

# %%
plt.figure(figsize= (12,8))
sns.heatmap(data = df0.corr(),annot=True)
# Out:
# <AxesSubplot:>
